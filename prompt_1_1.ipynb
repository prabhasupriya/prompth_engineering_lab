# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhasupriya/prompth_engineering_lab/blob/main/prompt_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

import os

# %%
os.environ["GEMINI_API_KEY"] = "enter_your_api_key" #get from the aistudio.com

# %%
from google import genai

# %%
client = genai.Client()

# %%
from google import genai

client = genai.Client(api_key=""enter_your_api_key" #get from the aistudio.com
)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="what is gen ai!"
)

# %%
print(response.text)
# Out:
# **Gen AI** stands for **Generative Artificial Intelligence**.
#
# In simple terms, it's a type of artificial intelligence that can **create new, original content** rather than just analyzing or classifying existing data.
#
# Here's a breakdown:
#
# 1.  **Generative:** This is the key word. Unlike traditional AI that might *recognize* a cat in a picture or *predict* a stock price, Generative AI *generates* things. It doesn't just copy; it synthesizes something novel.
#
# 2.  **Artificial Intelligence:** It's a computer system designed to perform tasks that typically require human intelligence, such as learning, problem-solving, and in this case, creativity.
#
# **How does it work (in a nutshell)?**
#
# Generative AI models are trained on **vast amounts of existing data**. For example:
# *   **Text models** (like ChatGPT) learn from billions of words, sentences, and documents.
# *   **Image models** (like DALL-E 2 or Midjourney) learn from millions of images and their descriptions.
#
# ...

# %% [markdown]
# baseline prompt with an enhanced prompt **bold text**

# %%
# !pip install -U google-genai

from google import genai

import os

# %%
os.environ["GEMINI_API_KEY"] = "enter_your_api_key" #get from the aistudio.com

# %%
client = genai.Client(
    api_key=os.environ["GEMINI_API_KEY"]
)

baseline_prompt = """
Write a one-paragraph bio of Ada Lovelace.
"""

# %%
# Generate baseline response
baseline_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=baseline_prompt
)

# %%
print(baseline_response.text)
# Out:
# Ada Lovelace, the daughter of Lord Byron, was a brilliant English mathematician and writer, widely recognized as the world's first computer programmer. Collaborating with Charles Babbage on his proposed mechanical general-purpose computer, the Analytical Engine, her extensive annotations to an article about the Engine contained what is considered the first algorithm intended to be carried out by a machine. More profoundly, Lovelace's notes demonstrated a visionary understanding of the Engine's potential beyond mere numerical calculation, conceptualizing it as a machine capable of manipulating symbols to compose music, create graphics, and advance science—a foresight that truly established her as a foundational figure in the history of computing.

# %%
enhanced_prompt = """
You are a professional historian.

Write a one-paragraph biography of Ada Lovelace.

Requirements:
1. Length: 120–150 words.
2. Mention her contributions to Charles Babbage's Analytical Engine.
3. Explain why she is considered the world's first computer programmer.
4. Use clear and formal language suitable for undergraduate students.
5. End with one sentence summarizing her historical significance.
"""

# %%
# Generate enhanced response
enhanced_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=enhanced_prompt
)

print("=" * 80)
print("BASELINE PROMPT")
print("=" * 80)
print(baseline_prompt)
# Out:
# ...
# BASELINE PROMPT
# ...
#
# Write a one-paragraph bio of Ada Lovelace.

# %%
print("\nBASELINE OUTPUT")
print("-" * 80)
print(baseline_response.text)

print("\n\n")
# Out:
# BASELINE OUTPUT
# --------------------------------------------------------------------------------
# Ada Lovelace, the daughter of Lord Byron, was a brilliant English mathematician and writer, widely recognized as the world's first computer programmer. Collaborating with Charles Babbage on his proposed mechanical general-purpose computer, the Analytical Engine, her extensive annotations to an article about the Engine contained what is considered the first algorithm intended to be carried out by a machine. More profoundly, Lovelace's notes demonstrated a visionary understanding of the Engine's potential beyond mere numerical calculation, conceptualizing it as a machine capable of manipulating symbols to compose music, create graphics, and advance science—a foresight that truly established her as a foundational figure in the history of computing.

# %%
print("\n" + "=" * 80)
print("COMPARISON")
print("=" * 80)
# Out:
# ...
# COMPARISON
# ...

# %%
print("\nBASELINE OUTPUT")
print("-" * 80)
print(baseline_response.text)
# Out:
# BASELINE OUTPUT
# --------------------------------------------------------------------------------
# Ada Lovelace, the daughter of Lord Byron, was a brilliant English mathematician and writer, widely recognized as the world's first computer programmer. Collaborating with Charles Babbage on his proposed mechanical general-purpose computer, the Analytical Engine, her extensive annotations to an article about the Engine contained what is considered the first algorithm intended to be carried out by a machine. More profoundly, Lovelace's notes demonstrated a visionary understanding of the Engine's potential beyond mere numerical calculation, conceptualizing it as a machine capable of manipulating symbols to compose music, create graphics, and advance science—a foresight that truly established her as a foundational figure in the history of computing.

# %%
print("=" * 80)
print("ENHANCED PROMPT")
print("=" * 80)
print(enhanced_prompt)

print("\nENHANCED OUTPUT")
print("-" * 80)
print(enhanced_response.text)

print("\n" + "=" * 80)
print("COMPARISON")
print("=" * 80)

print("""
Baseline Prompt:
• Simple instruction
• Short response
• Limited details
• No formatting guidance

Enhanced Prompt:
• Includes role framing (Historian)
• Specifies length (120–150 words)
• Requests important facts
• Defines audience
• Gives formatting instructions
• Produces a more relevant, complete, and professional response
""")
# Out:
# ...
# ENHANCED PROMPT
# ...
#
# You are a professional historian.
#
# Write a one-paragraph biography of Ada Lovelace.
#
# Requirements:
# 1. Length: 120–150 words.
# 2. Mention her contributions to Charles Babbage's Analytical Engine.
# 3. Explain why she is considered the world's first computer programmer.
# 4. Use clear and formal language suitable for undergraduate students.
# 5. End with one sentence summarizing her historical significance.
#
#
# ENHANCED OUTPUT
# --------------------------------------------------------------------------------
# ...

# %%
baseline_prompt = """
Write a one-paragraph bio of Ada Lovelace.
"""

# Generate baseline response
baseline_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=baseline_prompt
)

print(baseline_response.text)

enhanced_prompt = """
You are a professional historian.

Write a one-paragraph biography of Ada Lovelace.

Requirements:
1. Length: 120–150 words.
2. Mention her contributions to Charles Babbage's Analytical Engine.
3. Explain why she is considered the world's first computer programmer.
4. Use clear and formal language suitable for undergraduate students.
5. End with one sentence summarizing her historical significance.
"""

# Generate enhanced response
enhanced_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=enhanced_prompt
)

print("=" * 80)
print("BASELINE PROMPT")
print("=" * 80)
print(baseline_prompt)

print("\nBASELINE OUTPUT")
print("-" * 80)
print(baseline_response.text)

print("\n\n")

print("=" * 80)
print("ENHANCED PROMPT")
print("=" * 80)
print(enhanced_prompt)

print("\nENHANCED OUTPUT")
print("-" * 80)
print(enhanced_response.text)

print("\n" + "=" * 80)
print("COMPARISON")
print("=" * 80)

print("""
Baseline Prompt:
• Simple instruction
• Short response
• Limited details
• No formatting guidance

Enhanced Prompt:
• Includes role framing (Historian)
• Specifies length (120–150 words)
• Requests important facts
• Defines audience
• Gives formatting instructions
• Produces a more relevant, complete, and professional response
""")
# Out:
# Ada Lovelace, the daughter of the poet Lord Byron, was a brilliant mathematician and writer whose visionary insights into computing were centuries ahead of her time. Collaborating with Charles Babbage on his Analytical Engine, she translated a French article about the machine, significantly augmenting it with her own "Notes." In these extensive annotations, Lovelace not only described how the machine could calculate Bernoulli numbers—an algorithm now recognized as the world's first computer program—but also astutely theorized the Engine's potential beyond mere arithmetic, foreseeing its capacity to manipulate symbols and generate music or art. Her groundbreaking work and understanding of what a 'computer' could truly be earned her recognition as arguably the first computer programmer.
# ...
# BASELINE PROMPT
# ...
#
# Write a one-paragraph bio of Ada Lovelace.
#
#
# BASELINE OUTPUT
# --------------------------------------------------------------------------------
# ...
